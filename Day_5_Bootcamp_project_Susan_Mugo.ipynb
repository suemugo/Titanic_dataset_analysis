# %% [markdown]
# <a href="https://colab.research.google.com/github/suemugo/Titanic_dataset_analysis/blob/main/Day_5_Bootcamp_project_Susan_Mugo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("Day 3 Dataset.csv")

# %%
print(df.head())
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
print(df.tail())
# Out:
#      survived  pclass     sex   age  sibsp  parch   fare embarked   class  \
# 886         0       2    male  27.0      0      0  13.00        S  Second
# 887         1       1  female  19.0      0      0  30.00        S   First
# 888         0       3  female   NaN      1      2  23.45        S   Third
# 889         1       1    male  26.0      0      0  30.00        C   First
# 890         0       3    male  32.0      0      0   7.75        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True

# %%
df.shape
# Out:
# (891, 15)

# %%
df.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# survived       0
# pclass         0
# sex            0
# age            0
# sibsp          0
# parch          0
# fare           0
# embarked       0
# class          0
# who            0
# adult_male     0
# deck           0
# embark_town    0
# alive          0
# alone          0
# dtype: int64

# %%
df[df['age']>30]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 6           0       1    male  54.0      0      0  51.8625        S   First
# 11          1       1  female  58.0      0      0  26.5500        S   First
# 21          1       2    male  34.0      0      0  13.0000        S  Second
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 862         1       1  female  48.0      0      0  25.9292        S   First
# 867         0       1    male  31.0      0      0  50.4958        S   First
# 871         1       1  female  47.0      1      1  52.5542        S   First
# 872         0       1    male  33.0      0      0   5.0000        S   First
# 879         1       1  female  56.0      0      1  83.1583        C   First
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df[df['sex']=='female']
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 1           1       1  female  38.0      1      0  71.2833        C  First
# 3           1       1  female  35.0      1      0  53.1000        S  First
# 10          1       3  female   4.0      1      1  16.7000        S  Third
# 11          1       1  female  58.0      0      0  26.5500        S  First
# 52          1       1  female  49.0      1      0  76.7292        C  First
# ..        ...     ...     ...   ...    ...    ...      ...      ...    ...
# 853         1       1  female  16.0      0      1  39.4000        S  First
# 862         1       1  female  48.0      0      0  25.9292        S  First
# 871         1       1  female  47.0      1      1  52.5542        S  First
# 879         1       1  female  56.0      0      1  83.1583        C  First
# 887         1       1  female  19.0      0      0  30.0000        S  First
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df.groupby('sex')['survived'].mean()
# Out:
# sex
# female    0.931818
# male      0.436170
# Name: survived, dtype: float64

# %%
df_sorted=df.sort_values(by='age', ascending=True)
df_sorted.head()
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked   class  \
# 305         1       1    male  0.92      1      2  151.5500        S   First
# 183         1       2    male  1.00      2      1   39.0000        S  Second
# 205         0       3  female  2.00      0      1   10.4625        S   Third
# 297         0       1  female  2.00      1      2  151.5500        S   First
# 340         1       2    male  2.00      1      1   26.0000        S  Second
#
#        who  adult_male deck  embark_town alive  alone
# 305  child       False    C  Southampton   yes  False
# 183  child       False    F  Southampton   yes  False
# 205  child       False    G  Southampton    no  False
# 297  child       False    C  Southampton    no  False
# 340  child       False    F  Southampton   yes  False

# %%
df['family_size']=df['sibsp']+df['parch']
df.head()
# Out:
#     survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 1          1       1  female  38.0      1      0  71.2833        C  First
# 3          1       1  female  35.0      1      0  53.1000        S  First
# 6          0       1    male  54.0      0      0  51.8625        S  First
# 10         1       3  female   4.0      1      1  16.7000        S  Third
# 11         1       1  female  58.0      0      0  26.5500        S  First
#
#       who  adult_male deck  embark_town alive  alone  family_size
# 1   woman       False    C    Cherbourg   yes  False            1
# 3   woman       False    C  Southampton   yes  False            1
# 6     man        True    E  Southampton    no   True            0
# 10  child       False    G  Southampton   yes  False            2
# 11  woman       False    C  Southampton   yes   True            0

# %%
df['fare'].max()
# Out:
# 512.3292

# %%
df.to_csv('cleaned')

# %% [markdown]
# VISUALIZATION

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#surviavl rate
survival_rate = df ['survived'] . value_counts(normalize=True)*100
survival_rate.plot(kind='bar')
plt.title('survival percentage')
plt.ylabel('Percentage')
plt.show()

# %%
# survival Percentage - 65% of people survived

# %%
sns.barplot(x='sex', y='survived', data=df)
plt.title('survival rate by gender')
plt.show()

# %%
# Survival by gender:  Females had a significantly higher survival rate (approximately 93.7%) compared to males (approximately 42.5%)

# %%
sns.barplot(x='class', y='survived', data=df)
plt.title('Survival Rate by Class')
plt.show()

# %%
# Survival rate by class: second class(medium class people) had higher survival rate, followed by First class. This implies socioeconomic status or location on the ship played a role.

# %%
sns.boxplot(x='pclass', y='fare', data=df)
plt.title('Fare Distribution by Class')
plt.show()

# %%
# class 1 people paid more fare

# %%
sns.barplot(x='family_size', y='survived', data=df)
plt.title('survival rate by familt size')
plt.show()

# %%
sns.histplot(df['age'], color='green')
plt.title('Age Distribution')
plt.show()
#

# %%
sns.histplot(data=df, x='age', hue='survived',palette=['red','yellow'],bins=20)
plt.title('age Distribution by survival')
plt.show()

# %%
# yellow signifies people survived while red people who did not survive by age

# %%
survival=df['survived'].value_counts()
plt.pie(survival,labels=['survived','not survived'],autopct='%1.1f%%', colors=['green','blue'])
plt.title('survival percentage')
plt.show()

# %% [markdown]
# ### **Correlation Heatmap of Numerical Features**

# %%
numerical_cols = df.select_dtypes(include=np.number).columns

corr_matrix = df[numerical_cols].corr()

# heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=.5)
plt.title('Correlation Heatmap of Numerical Features')
plt.show()

# %%
# There is a negative correlation (-0.23) between survived and age. This suggests that younger passengers might have had a slightly higher chance of survival.
#  There's a positive correlation (0.13) between survived and fare. This implies that passengers who paid higher fares (often associated with higher classes) had a better chance of survival.
# There is a negative correlation (-0.03) between survived and pclass. Since pclass 1 is 'First' class and 3 is 'Third' class, this indicates that passengers in lower numerical classes, ha better survival rate which aligns with our previous bar plot analysis
# The combined family_size also shows a positive correlation (0.10) with survival. This suggests that having a small family aboard might have slightly increased survival chances, possibly due to support during evacuation.

# %%
sns.scatterplot(x='age',y='fare', data=df)
plt.title('age vs fare')
plt.show()

# %% [markdown]
# ### **Survival Rate by Embark Town**

# %%
sns.barplot(x='embark_town', y='survived', data=df)
plt.title('Survival Rate by Embarkation Town')
plt.xlabel('Embark Town')
plt.ylabel('Survival Rate')
plt.show()

# %%
# Cherbourg (C) has the highest survival rate, followed by Southampton (S).
# Queenstown (Q) has the lowest survival rate among the three embarkation towns.

# %% [markdown]
# Model

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %%
df['embarked'].fillna('S', inplace=True)
# Out:
# /tmp/ipykernel_1186/1318748835.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['embarked'].fillna('S', inplace=True)

# %%
df['deck'].fillna('Unknown', inplace=True)
# Out:
# /tmp/ipykernel_1186/1839536339.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['deck'].fillna('Unknown', inplace=True)

# %%
df.drop(['deck','class','who','adult_male','embark_town','alive'], axis=1, inplace=True)

# %%
df['sex']=df['sex'].map({'male':0,'female':1})
df['embarked']=df['embarked'].map({'S':0,'C':1,'Q':2})
df['alone']=df['alone'].map({False:0,True:1})

# %%
x=df.drop('survived', axis=1)
y=df['survived']

# %%
x_train, x_test, y_train, y_test = train_test_split(
    x, y, test_size=0.2, random_state=42)

# %%
model=LogisticRegression(max_iter=10000)
model.fit(x_train, y_train)
# Out:
# LogisticRegression(max_iter=10000)

# %%
y_pred=model.predict(x_test)

# %%
print('accuracy:', accuracy_score(y_test, y_pred))
# Out:
# accuracy: 0.6216216216216216

# %%
cm=confusion_matrix(y_test, y_pred)
print('confusion matrix:\n', cm)
# Out:
# confusion matrix:
#  [[ 8  5]
#  [ 9 15]]

# %%
cm=confusion_matrix(y_test, y_pred)
sns.heatmap(cm, annot=True, fmt='d', cmap='Reds')
plt.title('confusion matrix')
plt.show()

# %%
from sklearn.ensemble import RandomForestClassifier

# %% [markdown]
# # Initialize and train a Random Forest Classifier

# %%
rf_model = RandomForestClassifier(random_state=42)
rf_model.fit(x_train, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
rf_y_pred = rf_model.predict(x_test)

# %%
print('Random Forest Accuracy:', accuracy_score(y_test, rf_y_pred))
# Out:
# Random Forest Accuracy: 0.7027027027027027

# %%
rf_cm = confusion_matrix(y_test, rf_y_pred)
print('Random Forest Confusion Matrix:\n', rf_cm)
sns.heatmap(rf_cm, annot=True, fmt='d', cmap='Blues')
plt.title('Random Forest Confusion Matrix')
plt.show()
# Out:
# Random Forest Confusion Matrix:
#  [[ 5  8]
#  [ 3 21]]
